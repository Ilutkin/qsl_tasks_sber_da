# %% [markdown]
# # Задание 1
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# # Задание 2
# * Выберите регион
# * Сравните среднюю цену квадратного метра в городах этого региона
# * Определите количество строящихся объектов и квартир в регионах
# * Определите объем строящегося жилья в квадратных метрах
#
# # Задание 3 *
# * Напишете скрипт, который сможет ежедневно собирать данные по цене, количестве и объему строящихся объектов самостоятельно и ежедневно
# * Попробуйте ускорить процесс
# * Добавьте возможность добавления данных в БД с указанием текущей даты.

# %%
import requests
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# %% [markdown]
# ## Список объектов

# %%
offset_ = 2001
limit_ = 1000
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()

# %%
objects_data.keys()
# Out:
# dict_keys(['data', 'errcode'])

# %%
# Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
objects_list = pd.json_normalize(objects_data.get('data').get('list'))
# objects_list.set_index('objId', inplace=True)
objects_list
# Out:
#      objId  rpdRegionCd                                            objAddr  \
# 0    44876           72                      п Московский, ул Новая, д. 17
# 1    39480           29   г Архангельск, ул Романа Куликова, блок-секция 4
# 2    42038           29   г Архангельск, ул Романа Куликова, блок-секция А
# 3    42036           29   г Архангельск, ул Романа Куликова, блок-секция 5
# 4    36633           69  г Тверь, район Пролетарский, улица Макарова, д...
# ..     ...          ...                                                ...
# 995  43344           36                г Воронеж, улица Шидловского, д. 11
# 996  42227           25            г Уссурийск, Александра Францева, д. 32
# 997  37789           36                       г Воронеж, ул Беговая, д. 59
# 998  43991           54                         г Новосибирск, ул Аэропорт
# 999  40171           25            г Уссурийск, Александра Францева, д. 32
#
#                                           objCommercNm  objFloorMin  \
# 0                                        ЖК "Листопад"            1
# 1    Жилой комплекс"Арктический"_Жилой комплекс Арк...           11
# 2    Жилой комплекс"Арктический"_Жилой комплекс Арк...           11
# 3    Жилой комплекс"Арктический"_Жилой комплекс Арк...           12
# 4                                                  NaN            3
# ..                                                 ...          ...
# 995                             Жилой квартал "Озерки"           18
# 996                                                NaN           25
# 997                             Жилой дом "на Беговой"           13
# 998                                          ЖК Высота           27
# 999                                                NaN           25
#
#      objFloorMax  objElemLivingCnt objReady100PercDt  objSquareLiving  \
# 0              9                96        2023-03-31          4324.80
# 1             11                26        2022-06-30          2041.63
# 2             11                56        2022-12-31          2135.80
# 3             12                56        2023-03-31          2963.76
# 4              3                 0        2022-12-31             0.00
# ..           ...               ...               ...              ...
# 995           18               120        2022-09-30          6441.00
# 996           25               226        2023-09-30         11485.80
# 997           16               150        2022-09-30          9500.90
# 998           27               246        2023-12-31         10330.02
# 999           25               226        2023-09-30         11485.80
#
#      objCompensFundFlg  ...  developer.orgForm.id  \
# 0                    0  ...                     4
# 1                    1  ...                     1
# 2                    0  ...                     1
# 3                    0  ...                     1
# 4                    1  ...                     4
# ..                 ...  ...                   ...
# 995                  0  ...                     4
# 996                  0  ...                     4
# 997                  0  ...                     4
# 998                  0  ...                     4
# 999                  0  ...                     4
#
#                    developer.orgForm.fullForm  developer.orgForm.shortForm  \
# 0    Общество с ограниченной ответственностью                          ООО
# 1                        Акционерное общество                           АО
# 2                        Акционерное общество                           АО
# 3                        Акционерное общество                           АО
# 4    Общество с ограниченной ответственностью                          ООО
# ..                                        ...                          ...
# 995  Общество с ограниченной ответственностью                          ООО
# 996  Общество с ограниченной ответственностью                          ООО
# 997  Общество с ограниченной ответственностью                          ООО
# 998  Общество с ограниченной ответственностью                          ООО
# 999  Общество с ограниченной ответственностью                          ООО
#
#     developer.companyGroup developer.devInn  \
# 0             6.021191e+09       7224011820
# 1             1.560562e+08       2902001119
# 2             1.560562e+08       2902001119
# 3             1.560562e+08       2902001119
# 4             5.882189e+09       6905013230
# ..                     ...              ...
# 995           4.252132e+09       3662276888
# 996           3.040000e+02       2511106931
# 997                    NaN       3662108298
# 998           7.325886e+09       5405059643
# 999           3.040000e+02       2511106931
#
#      developer.bankruptStage.bankruptStageCd  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 995                                      NaN
# 996                                      NaN
# 997                                      NaN
# 998                                      NaN
# 999                                      NaN
#
#      developer.bankruptStage.bankruptStageDesc  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 995                                        NaN
# 996                                        NaN
# 997                                        NaN
# 998                                        NaN
# 999                                        NaN
#
#     developer.bankruptStage.bankruptLawUrl  developer.orgBankruptMsgDttm  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# ..                                     ...                           ...
# 995                                    NaN                           NaN
# 996                                    NaN                           NaN
# 997                                    NaN                           NaN
# 998                                    NaN                           NaN
# 999                                    NaN                           NaN
#
#     complexShortName
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 995              NaN
# 996              NaN
# 997              NaN
# 998              NaN
# 999              NaN
#
# [1000 rows x 35 columns]

# %%
obj_ID = list(objects_list['objId'])

# %% [markdown]
# # Данные по определенному объекту

# %%
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/25002'

# %%
obj_description = pd.DataFrame()
description_obj_list = []
for ids in tqdm(obj_ID):
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{ids}'
    res = requests.get(url)
    v = res.json()
    description_obj_list.append(v)
obj_description = pd.json_normalize(description_obj_list)
obj_description.tail()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#     errcode  data.id  data.pdId  data.developer.devId  \
# 995       0    43344     512939                  9567
# 996       0    42227     472198                 10204
# 997       0    37789     394566                 10819
# 998       0    43991     533546                 13254
# 999       0    40171     460971                 10204
#
#     data.developer.devShortCleanNm data.developer.devShortNm  \
# 995             СЗ ВЫБОРСТРОЙ СЕМЬ        СЗ ВЫБОРСТРОЙ СЕМЬ
# 996                      СЗ ВЫСОТА                 СЗ ВЫСОТА
# 997                      СЗ ВЫСОТА                 СЗ ВЫСОТА
# 998                      СЗ ВЫСОТА                 СЗ ВЫСОТА
# 999                      СЗ ВЫСОТА                 СЗ ВЫСОТА
#
#                     data.developer.devFullCleanNm  data.developer.problObjCnt  \
# 995  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВЫБОРСТРОЙСЕМЬ                           0
# 996          СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВЫСОТА                           0
# 997          СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВЫСОТА                           0
# 998          СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВЫСОТА                           0
# 999          СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВЫСОТА                           0
#
#      data.developer.buildObjCnt  data.developer.comissObjCnt  ...  \
# 995                           1                            1  ...
# 996                           3                            1  ...
# 997                           1                            0  ...
# 998                           1                            0  ...
# 999                           3                            1  ...
#
#     data.metro.colors data.transportDistIndex data.transportDistIndexValue  \
# 995               NaN                     NaN                          NaN
# 996               NaN                     NaN                          NaN
# 997               NaN                     NaN                          NaN
# 998         [#CD0505]                  6 / 10                          6.0
# 999               NaN                     NaN                          NaN
#
#     data.greenAreaIndexValue data.developer.bankruptStage.bankruptStageCd  \
# 995                      NaN                                          NaN
# 996                      NaN                                          NaN
# 997                      NaN                                          NaN
# 998                      NaN                                          NaN
# 999                      NaN                                          NaN
#
#     data.developer.bankruptStage.bankruptStageDesc  \
# 995                                            NaN
# 996                                            NaN
# 997                                            NaN
# 998                                            NaN
# 999                                            NaN
#
#     data.developer.bankruptStage.bankruptLawUrl  \
# 995                                         NaN
# 996                                         NaN
# 997                                         NaN
# 998                                         NaN
# 999                                         NaN
#
#     data.developer.orgBankruptMsgDttm data.airQualityIndexValue  \
# 995                               NaN                       NaN
# 996                               NaN                       NaN
# 997                               NaN                       NaN
# 998                               NaN                       NaN
# 999                               NaN                       NaN
#
#      data.complexShortNm
# 995                  NaN
# 996                  NaN
# 997                  NaN
# 998                  NaN
# 999                  NaN
#
# [5 rows x 109 columns]

# %%
# Cохранить ее в pandas dataframe
all_obj_info = pd.merge(objects_list,obj_description, left_on=['objId'], right_on=['data.id'], left_index=False, right_index=False, how='left').copy()
all_obj_info.head(5)
# Out:
#    objId  rpdRegionCd                                            objAddr  \
# 0  44876           72                      п Московский, ул Новая, д. 17
# 1  39480           29   г Архангельск, ул Романа Куликова, блок-секция 4
# 2  42038           29   г Архангельск, ул Романа Куликова, блок-секция А
# 3  42036           29   г Архангельск, ул Романа Куликова, блок-секция 5
# 4  36633           69  г Тверь, район Пролетарский, улица Макарова, д...
#
#                                         objCommercNm  objFloorMin  \
# 0                                      ЖК "Листопад"            1
# 1  Жилой комплекс"Арктический"_Жилой комплекс Арк...           11
# 2  Жилой комплекс"Арктический"_Жилой комплекс Арк...           11
# 3  Жилой комплекс"Арктический"_Жилой комплекс Арк...           12
# 4                                                NaN            3
#
#    objFloorMax  objElemLivingCnt objReady100PercDt  objSquareLiving  \
# 0            9                96        2023-03-31          4324.80
# 1           11                26        2022-06-30          2041.63
# 2           11                56        2022-12-31          2135.80
# 3           12                56        2023-03-31          2963.76
# 4            3                 0        2022-12-31             0.00
#
#    objCompensFundFlg  ...  data.metro.colors  data.transportDistIndex  \
# 0                  0  ...                NaN                      NaN
# 1                  1  ...                NaN                      NaN
# 2                  0  ...                NaN                      NaN
# 3                  0  ...                NaN                      NaN
# 4                  1  ...                NaN                      NaN
#
#    data.transportDistIndexValue data.greenAreaIndexValue  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
#   data.developer.bankruptStage.bankruptStageCd  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    data.developer.bankruptStage.bankruptStageDesc  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    data.developer.bankruptStage.bankruptLawUrl  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   data.developer.orgBankruptMsgDttm  data.airQualityIndexValue  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
#
#   data.complexShortNm
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 144 columns]

# %%
# Cохранить pandas dataframe в excel
all_obj_info.to_excel('DMRF.xlsx', engine='xlsxwriter')

# %%
# Cохранить pandas dataframe в pickle
pd.to_pickle(all_obj_info, "./all_obj_info.pkl")

# %%
# Задание 2
# Выберите регион
all_obj_52_reg = all_obj_info[all_obj_info['rpdRegionCd'] == 52].copy()
all_obj_52_reg.head(3)
# Out:
#      objId  rpdRegionCd                                        objAddr  \
# 192  35624           52             г Нижний Новгород, ул Минина, д. 6
# 193  35625           52  г Нижний Новгород, наб Верхне-Волжская, д. 2а
# 194  13972           52                       г Бор, ул Ленина, д. 58А
#
#                                          objCommercNm  objFloorMin  \
# 192  Жилой комплекс «Георгиевский», ЖК «Георгиевский»            2
# 193  Жилой комплекс «Георгиевский», ЖК «Георгиевский»           10
# 194                          ЖК «Сергиевская Слобода»            7
#
#      objFloorMax  objElemLivingCnt objReady100PercDt  objSquareLiving  \
# 192            9                29        2022-06-30          2640.25
# 193           10               114        2022-06-30         12444.80
# 194            7               150        2022-06-30         11765.88
#
#      objCompensFundFlg  ...  data.metro.colors  data.transportDistIndex  \
# 192                  0  ...          [#D80707]                   9 / 10
# 193                  0  ...          [#D80707]                   8 / 10
# 194                  1  ...                NaN                      NaN
#
#      data.transportDistIndexValue data.greenAreaIndexValue  \
# 192                           9.0                      NaN
# 193                           8.0                      NaN
# 194                           NaN                      NaN
#
#     data.developer.bankruptStage.bankruptStageCd  \
# 192                                          NaN
# 193                                          NaN
# 194                                          NaN
#
#      data.developer.bankruptStage.bankruptStageDesc  \
# 192                                             NaN
# 193                                             NaN
# 194                                             NaN
#
#      data.developer.bankruptStage.bankruptLawUrl  \
# 192                                          NaN
# 193                                          NaN
# 194                                          NaN
#
#     data.developer.orgBankruptMsgDttm  data.airQualityIndexValue  \
# 192                               NaN                        NaN
# 193                               NaN                        NaN
# 194                               NaN                        NaN
#
#     data.complexShortNm
# 192                 NaN
# 193                 NaN
# 194                 NaN
#
# [3 rows x 144 columns]

# %%
all_obj_52_reg['city_name'] = all_obj_52_reg['objAddr'].str.extract(r'\bг\s*([^,]+)')
all_obj_52_reg.head(3)
# Out:
#      objId  rpdRegionCd                                        objAddr  \
# 192  35624           52             г Нижний Новгород, ул Минина, д. 6
# 193  35625           52  г Нижний Новгород, наб Верхне-Волжская, д. 2а
# 194  13972           52                       г Бор, ул Ленина, д. 58А
#
#                                          objCommercNm  objFloorMin  \
# 192  Жилой комплекс «Георгиевский», ЖК «Георгиевский»            2
# 193  Жилой комплекс «Георгиевский», ЖК «Георгиевский»           10
# 194                          ЖК «Сергиевская Слобода»            7
#
#      objFloorMax  objElemLivingCnt objReady100PercDt  objSquareLiving  \
# 192            9                29        2022-06-30          2640.25
# 193           10               114        2022-06-30         12444.80
# 194            7               150        2022-06-30         11765.88
#
#      objCompensFundFlg  ...  data.transportDistIndex  \
# 192                  0  ...                   9 / 10
# 193                  0  ...                   8 / 10
# 194                  1  ...                      NaN
#
#      data.transportDistIndexValue  data.greenAreaIndexValue  \
# 192                           9.0                       NaN
# 193                           8.0                       NaN
# 194                           NaN                       NaN
#
#     data.developer.bankruptStage.bankruptStageCd  \
# 192                                          NaN
# 193                                          NaN
# 194                                          NaN
#
#     data.developer.bankruptStage.bankruptStageDesc  \
# 192                                            NaN
# 193                                            NaN
# 194                                            NaN
#
#      data.developer.bankruptStage.bankruptLawUrl  \
# 192                                          NaN
# 193                                          NaN
# 194                                          NaN
#
#      data.developer.orgBankruptMsgDttm data.airQualityIndexValue  \
# 192                                NaN                       NaN
# 193                                NaN                       NaN
# 194                                NaN                       NaN
#
#      data.complexShortNm        city_name
# 192                  NaN  Нижний Новгород
# 193                  NaN  Нижний Новгород
# 194                  NaN              Бор
#
# [3 rows x 145 columns]

# %%
# Сравните среднюю цену квадратного метра в городах этого региона
comparison = pd.pivot_table(all_obj_52_reg, index=["city_name"], values=["data.objPriceAvg"],  aggfunc=[np.mean, len])
comparison
# Out:
#                                  mean              len
#                      data.objPriceAvg data.objPriceAvg
# city_name
# Арзамас                  53315.000000                2
# Бор                      52682.000000                1
# Нижний Новгород         116556.928571               14
# ород Нижний Новгород     92552.000000                1
# Кстово                            NaN                1

# %%
# Определите количество строящихся объектов и квартир в регионах
all_obj_reg = pd.pivot_table(all_obj_info, 
                             index=['data.developer.regRegionDesc'], 
                             values=['objElemLivingCnt', 'objSquareLiving', 'objId'],  
                             aggfunc={'objElemLivingCnt': np.sum, 'objSquareLiving': np.sum, 'objId': len}, 
                             fill_value=0)
all_obj_reg.sort_values(by='objSquareLiving', ascending = False).head(30)
# Out:
#                               objElemLivingCnt  objId  objSquareLiving
# data.developer.regRegionDesc
# Москва город                             46566    101       2355062.05
# Московская область                       14803     98        743979.31
# Краснодарский край                       15471     56        712949.26
# Санкт-Петербург город                    11604     52        536468.61
# Свердловская область                      8100     42        437509.70
# Новосибирская область                     6916     40        362501.63
# Приморский край                           6425     33        295113.99
# Ростовская область                        5112     28        256847.89
# Воронежская область                       4515     26        250830.10
# Владимирская область                      3662     14        211420.19
# Нижегородская область                     3554     19        201571.73
# Алтайский край                            3826     23        195479.92
# Удмуртская Республика                     3869     19        186492.69
# Ярославская область                       3667     13        175207.65
# Калининградская область                   3146     29        161391.45
# Самарская область                         2688     12        157305.15
# Красноярский край                         2688     13        153921.05
# Бурятия Республика                        2521     14        128272.62
# Рязанская область                         2350      6        127237.83
# Башкортостан Республика                   2524     11        124576.49
# Татарстан Республика                      2160     28        122187.21
# Сахалинская область                       2112     24        109170.82
# Тульская область                          1910     13        100788.99
# Волгоградская область                     1811     10        100479.57
# Иркутская область                         1671     36         91683.41
# Брянская область                          1540      8         89890.02
# Архангельская область                     1750     13         80685.41
# Тюменская область                         1602      9         77893.66
# Крым Республика                           1666     11         75927.67
# Белгородская область                      1357     19         72107.19
